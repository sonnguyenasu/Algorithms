# %% [markdown]
# Runway reservation system
# - Airport with a single landings
# - Reserve request specifies landing time t
# - Add t to the set R if no other landings are scheduled within k  ns
# - Remove the reservation from set R after the plane lands
# - if |R| = n then we need to finish in O(lgn) times

# %% [markdown]
# BST allows insertion in O(lg n) times and serch in O(lg n) times also
# node x: key(x)
# pointers: left[i], right[i] and parent[i]
#
# Invariant: For all nodes x, if y on the left subtree of x: key(y) <= key(x)
#
# if y is on the right, key(y) > key(x)

# %% [markdown]
# Augment the BST structure:
#
#     49(5)
#
# 46(1)       79(3)
#
#       64(1)     83(1)
#
# insert or delete modify "size" numbers.
#
#             49(5+1)
#
#       46(1+1)        79(3)
#
#  43(1)          64(1)     83(1)

# %%
plt.plot(data1['Al'],label = 'Al')
plt.plot(data1['Wood'], label = 'wood')
plt.plot(data1['Acrylic'], label = 'acrylic')
plt.plot(data1['Styrofoam'], label = 'Styrofoam')
plt.plot(data1['Concrete'], label = 'Concrete', color = 'pink')
plt.grid('true')
plt.legend()
plt.show()
